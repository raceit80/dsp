# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #import plotting functionality

#render plotting automatically
# %matplotlib inline

import matplotlib as mpl #additional plotting functionality

mpl.rcParams['figure.dpi'] = 200 #high resolution figures
df = pd.read_csv('Data/cleaned_cc_1.csv')
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24      2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26     -1      2
# 2  85698822-43f5      90000    2          2         2   34      0      0
# 3  0737c11b-be42      50000    2          2         1   37      0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57     -1      0
#
#    PAY_3  PAY_4  ...  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0     -1     -1  ...         0         0         0         0
# 1      0      0  ...      1000      1000         0      2000
# 2      0      0  ...      1000      1000      1000      5000
# 3      0      0  ...      1200      1100      1069      1000
# 4     -1      0  ...     10000      9000       689       679
#
#    default payment next month  EDUCATION_CAT  graduate school  high school  \
# 0                           1     university                0            0
# 1                           1     university                0            0
# 2                           0     university                0            0
# 3                           0     university                0            0
# 4                           0     university                0            0
#
#    others  university
# 0       0           1
# 1       0           1
# 2       0           1
# 3       0           1
# 4       0           1
#
# [5 rows x 30 columns]

# %%
pay_feats = ['PAY_1','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']

# %%
df[pay_feats].describe()
# Out:
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean      -0.017777     -0.133363     -0.167679     -0.225023     -0.269764
# std        1.126769      1.198640      1.199165      1.167897      1.131735
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#               PAY_6
# count  26664.000000
# mean      -0.293579
# std        1.150229
# min       -2.000000
# 25%       -1.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %%
df[pay_feats[0]].value_counts().sort_index()
# Out:
# -2     2476
# -1     5047
#  0    13087
#  1     3261
#  2     2378
#  3      292
#  4       63
#  5       23
#  6       11
#  7        9
#  8       17
# Name: PAY_1, dtype: int64

# %%
df[pay_feats[0]].hist()

# %%
pay_1_bins = np.array(range(-2,10)) - 0.5
pay_1_bins
# Out:
# array([-2.5, -1.5, -0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,
#         8.5])

# %%
mpl.rcParams['font.size'] = 4
df[pay_feats].hist(bins=pay_1_bins, layout=(2,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc65f60b490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc65f7ae4f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc65f7d7be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc65f80d3a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc65f836b20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc65f9a2220>]],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26664 entries, 0 to 26663
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          26664 non-null  object
#  1   LIMIT_BAL                   26664 non-null  int64
#  2   SEX                         26664 non-null  int64
#  3   EDUCATION                   26664 non-null  int64
#  4   MARRIAGE                    26664 non-null  int64
#  5   AGE                         26664 non-null  int64
#  6   PAY_1                       26664 non-null  int64
#  7   PAY_2                       26664 non-null  int64
#  8   PAY_3                       26664 non-null  int64
#  9   PAY_4                       26664 non-null  int64
#  10  PAY_5                       26664 non-null  int64
#  11  PAY_6                       26664 non-null  int64
#  12  BILL_AMT1                   26664 non-null  int64
#  13  BILL_AMT2                   26664 non-null  int64
#  14  BILL_AMT3                   26664 non-null  int64
#  15  BILL_AMT4                   26664 non-null  int64
#  16  BILL_AMT5                   26664 non-null  int64
#  17  BILL_AMT6                   26664 non-null  int64
#  18  PAY_AMT1                    26664 non-null  int64
#  19  PAY_AMT2                    26664 non-null  int64
#  20  PAY_AMT3                    26664 non-null  int64
#  21  PAY_AMT4                    26664 non-null  int64
#  22  PAY_AMT5                    26664 non-null  int64
#  23  PAY_AMT6                    26664 non-null  int64
#  24  default payment next month  26664 non-null  int64
#  25  EDUCATION_CAT               26664 non-null  object
#  26  graduate school             26664 non-null  int64
#  27  high school                 26664 non-null  int64
#  28  others                      26664 non-null  int64
#  29  university                  26664 non-null  int64
# dtypes: int64(28), object(2)
# memory usage: 6.1+ MB

# %%
bill_amt_feats = ['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6' ]
df[bill_amt_feats].describe()
# Out:
#            BILL_AMT1      BILL_AMT2      BILL_AMT3      BILL_AMT4  \
# count   26664.000000   26664.000000   26664.000000   26664.000000
# mean    51405.730723   49300.001500   47026.340047   43338.894539
# std     73633.687106   70934.549534   68705.359524   64275.250740
# min   -165580.000000  -69777.000000 -157264.000000 -170000.000000
# 25%      3580.000000    2999.750000    2627.250000    2341.750000
# 50%     22361.000000   21150.000000   20079.500000   19037.000000
# 75%     67649.750000   64395.500000   60360.000000   54727.500000
# max    746814.000000  671563.000000  855086.000000  706864.000000
#
#            BILL_AMT5      BILL_AMT6
# count   26664.000000   26664.000000
# mean    40338.136701   38889.872337
# std     60705.944083   59432.541657
# min    -81334.000000 -339603.000000
# 25%      1745.000000    1256.000000
# 50%     18066.000000   17005.000000
# 75%     50290.500000   49253.750000
# max    823540.000000  699944.000000

# %%
df[bill_amt_feats].hist(bins=20, layout=(2,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc660197cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6601d7eb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc660307370>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6603337f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc66035fc40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc66038c130>]],
#       dtype=object)

# %%
pay_amt_feats = ['PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6']
df[pay_amt_feats].describe()
# Out:
#             PAY_AMT1      PAY_AMT2       PAY_AMT3       PAY_AMT4  \
# count   26664.000000  2.666400e+04   26664.000000   26664.000000
# mean     5704.085771  5.881110e+03    5259.514964    4887.048717
# std     16699.398632  2.121431e+04   17265.439561   15956.349371
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%      1000.000000  8.020000e+02     390.000000     294.750000
# 50%      2114.500000  2.007000e+03    1822.000000    1500.000000
# 75%      5027.000000  5.000000e+03    4556.250000    4050.500000
# max    873552.000000  1.227082e+06  889043.000000  621000.000000
#
#             PAY_AMT5       PAY_AMT6
# count   26664.000000   26664.000000
# mean     4843.729973    5257.843047
# std     15311.721795   17635.468185
# min         0.000000       0.000000
# 25%       242.750000     111.000000
# 50%      1500.000000    1500.000000
# 75%      4082.750000    4015.000000
# max    426529.000000  528666.000000

# %%
df[pay_amt_feats].hist(layout=(2,3), xrot=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc662094520>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6601588e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc66014caf0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6603131c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6617826a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc660135550>]],
#       dtype=object)

# %%
pay_zero_mask = df[pay_amt_feats] == 0
pay_zero_mask.sum()
# Out:
# PAY_AMT1    4656
# PAY_AMT2    4833
# PAY_AMT3    5293
# PAY_AMT4    5697
# PAY_AMT5    5981
# PAY_AMT6    6373
# dtype: int64

# %%
df[pay_amt_feats][~pay_zero_mask].apply(np.log10).hist(layout=(2,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc66394ebb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc663e60100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc663e97520>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc663ec4970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc663ef0dc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc663f2a190>]],
#       dtype=object)
